# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 

df = pd.read_csv('../data/Data_Cleaned.csv')

df
# Out:
#     Муниципалитет Этап олимпиады  Год проведения  Количество участников  \
# 0    Зеленодольск   Региональный            2019                    165
# 1    Зеленодольск   Региональный            2018                     58
# 2          Буинск  Муниципальный            2019                    126
# 3          Тетюши  Муниципальный            2017                     89
# 4          Буинск       Школьный            2015                    103
# ..            ...            ...             ...                    ...
# 891       Балтаси       Школьный            2015                    182
# 892   Лениногорск       Школьный            2024                    158
# 893   Менделеевск       Школьный            2015                    151
# 894       Елабуга   Региональный            2024                    101
# 895          Арск   Региональный            2021                    116
#
#      Количество призёров  Процент призёров  Средний балл по этапу
# 0                     58             35.15                  89.30
# 1                     16             27.59                  44.23
# 2                     53             42.06                  44.53
# 3                     38             42.70                  60.02
# 4                     23             22.33                  88.37
# ..                   ...               ...                    ...
# 891                    1              0.55                  98.36
# 892                   57             36.08                  58.64
# 893                   64             42.38                  -1.00
# 894                   12             11.88                  40.51
# 895                   50             43.10                  56.85
#
# [896 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 896 entries, 0 to 895
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Муниципалитет          896 non-null    object
#  1   Этап олимпиады         896 non-null    object
#  2   Год проведения         896 non-null    int64
#  3   Количество участников  896 non-null    int64
#  4   Количество призёров    896 non-null    int64
#  5   Процент призёров       896 non-null    float64
#  6   Средний балл по этапу  896 non-null    float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 49.1+ KB

# %%
df.describe()
# Out:
#        Год проведения  Количество участников  Количество призёров  \
# count      896.000000             896.000000           896.000000
# mean      2019.625000             121.496652            30.452009
# std          2.798643              43.534665            21.947931
# min       2015.000000              50.000000             1.000000
# 25%       2017.000000              84.000000            12.000000
# 50%       2020.000000             120.000000            26.000000
# 75%       2022.000000             159.000000            44.000000
# max       2024.000000             200.000000            95.000000
#
#        Процент призёров  Средний балл по этапу
# count        896.000000             896.000000
# mean          24.942087              67.981763
# std           14.344640              20.746831
# min            0.550000              -1.000000
# 25%           12.477500              53.942500
# 50%           24.850000              68.460000
# 75%           37.140000              85.145000
# max           50.000000              99.890000

# %%
df.skew(numeric_only=True)
# Out:
# Год проведения          -0.104753
# Количество участников    0.098333
# Количество призёров      0.759170
# Процент призёров         0.015800
# Средний балл по этапу   -0.811094
# dtype: float64

# %%
df.kurtosis(numeric_only=True)
# Out:
# Год проведения          -1.157002
# Количество участников   -1.172110
# Количество призёров     -0.149653
# Процент призёров        -1.192169
# Средний балл по этапу    1.337737
# dtype: float64

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Муниципалитет            0
# Этап олимпиады           0
# Год проведения           0
# Количество участников    0
# Количество призёров      0
# Процент призёров         0
# Средний балл по этапу    0
# dtype: int64

# %%
df.hist(bins=50)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Корреляционная матрица')
plt.show()

# %%
df.hist(bins=50, figsize=(20,10))
plt.show()

# %%
selected_columns = ["Количество участников", "Количество призёров", "Процент призёров", "Средний балл по этапу"]

sns.pairplot(df[selected_columns])
plt.show()
